# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

# %% [markdown]
# ## Initialization

# %%
def initialize_wrd_emb(vocab_size, emb_size):
    WRD_EMB = np.random.uniform(size=(vocab_size, emb_size))
    return WRD_EMB

def initialize_dense(input_size, output_size):
    W = np.random.uniform(size=(output_size, input_size))
    b = np.random.uniform(size=(output_size, 1))
    return W, b

def initialize_parameters(vocab_size, emb_size):
    WRD_EMB = initialize_wrd_emb(vocab_size, emb_size)
    W, b = initialize_dense(emb_size, vocab_size)
    
    parameters = {}
    parameters['WRD_EMB'] = WRD_EMB
    parameters['W'] = W
    parameters['b'] = b
    
    return parameters

# %% [markdown]
# ## Forward Propagation

# %%
def ind_to_word_vecs(inds, parameters):
    """
    inds -- shape: (CBOW_N, number of examples)
    """
    WRD_EMB = parameters['WRD_EMB']
    word_vecs = np.take(WRD_EMB, inds, axis=0)
    word_vecs = word_vecs.reshape(WRD_EMB.shape[1], inds.shape[0], -1)
    
    assert(word_vecs.shape == (WRD_EMB.shape[1], inds.shape[0], inds.shape[1]))
    
    return word_vecs

def sum_(word_vecs):
    word_vecs_sum = np.sum(word_vecs, axis=1)
    word_vecs_sum = word_vecs_sum.reshape(word_vecs.shape[0], -1)
    
    assert(word_vecs_sum.shape == (word_vecs.shape[0], word_vecs.shape[2]))
    
    return word_vecs_sum

def linear_dense(word_vecs_sum, parameters):
    W, b = parameters['W'], parameters['b']
    Z = np.dot(W, word_vecs_sum) + b
    
    assert(Z.shape == (W.shape[0], word_vecs_sum.shape[1]))
    
    return W, b, Z

def softmax(Z):
    softmax_out = np.divide(np.exp(Z), np.sum(np.exp(Z), axis=0))
    
    assert(softmax_out.shape == Z.shape)
    
    return softmax_out

def forward_propagation(inds, parameters):
    word_vecs = ind_to_word_vecs(inds, parameters)
    word_vecs_sum = sum_(word_vecs)
    W, b, Z = linear_dense(word_vecs_sum, parameters)
    softmax_out = softmax(Z)
    
    caches = {}
    caches['inds'] = inds
    caches['word_vecs'] = word_vecs
    caches['word_vecs_sum'] = word_vecs_sum
    caches['W'] = W
    caches['b'] = b
    caches['Z'] = Z
    
    return softmax_out, caches

# %% [markdown]
# ## Cost Function

# %%
def cross_entropy(softmax_out, Y):
    m = softmax_out.shape[1]
    cost = -(1 / m) * np.sum(np.sum(Y * np.log(softmax_out), axis=1), axis=0)
    return cost

# %% [markdown]
# ## Backward Propagation

# %%
def softmax_backward(Y, caches):
    Z = caches['Z']
    dL_dZ = Z - Y
    
    assert(dL_dZ.shape == Z.shape)
    
    return dL_dZ

def dense_backward(dL_dZ, caches):
    W = caches['W']
    b = caches['b']
    word_vecs_sum = caches['word_vecs_sum']
    m = word_vecs_sum.shape[1]
    
    dL_dW = (1 / m) * np.dot(dL_dZ, word_vecs_sum.T)
    dL_db = (1 / m) * np.sum(dL_dZ, axis=1, keepdims=True)
    dL_dword_vecs_sum = np.dot(W.T, dL_dZ)

    assert(W.shape == dL_dW.shape)
    assert(b.shape == dL_db.shape)
    assert(word_vecs_sum.shape == dL_dword_vecs_sum.shape)
    
    return dL_dW, dL_db, dL_dword_vecs_sum

def sum_backward(dL_dword_vecs_sum, caches):
    word_vecs = caches['word_vecs']
    CBOW_N = word_vecs.shape[1]
    
    dL_dword_vecs = (1 / m) * np.ones((dL_dword_vecs_sum.shape[0], CBOW_N)) *\
        np.sum(dL_dword_vecs_sum, axis=1, keepdims=True)

    assert((word_vecs.shape[0], word_vecs.shape[1]) == dL_dword_vecs.shape[:2])
    
    return dL_dword_vecs

def backward_propagation(Y, caches):
    dL_dz = softmax_backward(Y, caches)
    dL_dW, dL_db, dL_dword_vecs_sum = dense_backward(dL_dz, caches)
    dL_dword_vecs = sum_backward(dL_dword_vecs_sum, caches)
    
    gradients = dict()
    gradients['dL_dW'] = dL_dW
    gradients['dL_db'] = dL_db
    gradients['dL_dword_vecs'] = dL_dword_vecs
    
    return gradients

def update_parameters(parameters, caches, gradients, learning_rate):
    CBOW_N = caches['inds'].shape[0]
    vocab_size, emb_size = parameters['WRD_EMB'].shape
    
    inds = caches['inds']
    updated_WRD_EMD = parameters['WRD_EMB'][inds.T, :] -\
        learning_rate * gradients['dL_dword_vecs'].T.reshape(1, CBOW_N, -1)
    parameters['WRD_EMB'][inds.flatten(), :] = updated_WRD_EMD.reshape(-1, emb_size)
    parameters['W'] -= learning_rate * gradients['dL_dW']
    parameters['b'] -= learning_rate * gradients['dL_db']

# %%
def cbow_model(X, Y, vocab_size, emb_size, learning_rate, epochs, parameters=None, print_cost=False):
    costs = []
    if not parameters:
        parameters = initialize_parameters(vocab_size, emb_size)
    
    for i in range(epochs):
        softmax_out, caches = forward_propagation(X, parameters)
        cost = cross_entropy(softmax_out, Y)
        gradients = backward_propagation(Y, caches)
        update_parameters(parameters, caches, gradients, learning_rate)
        
        costs.append(cost)
        if print_cost and i % 10000 == 0:
            print("Cost after iterations {}: {}".format(i, np.squeeze(cost)))
        
    return parameters

# %% [markdown]
# ### Toy data
# Sentence: I(0) would(1) like(2) to(3) get(4) a(5) better(6) job(7).
# vocab_size = 8
# ```
# [0, 2] [1]
# [1, 3] [2]
# [2, 4] [3]
# [3, 5] [4]
# [4, 6] [5]
# [5, 7] [6]
# ```

# %%
input_len = 2
vocab_size = 8
m = 6
emb_size = 15
X = np.array([[0, 1, 2, 3, 4, 5],
              [2, 3, 4, 5, 6, 7]]) # 2 x 6
Y = np.array([1, 2, 3, 4, 5, 6]) # 1 x 6
Y_one_hot = np.zeros((vocab_size, m))  # 8 x 6
Y_one_hot[Y.flatten(), np.arange(6)] = 1

# %% [markdown]
# ### Initialization Test

# %%
parameters = initialize_parameters(vocab_size, emb_size)

# %% [markdown]
# ### Forward Probagation Test

# %%
softmax_out, caches = forward_propagation(X, parameters)

# %% [markdown]
# ### Compute Cost Test

# %%
cost = cross_entropy(softmax_out, Y_one_hot)

# %% [markdown]
# ### Backward Probagation Test

# %%
gradients = backward_propagation(Y_one_hot, caches)

# %% [markdown]
# ### Model Test

# %%
cbow_model(X, Y_one_hot, vocab_size, emb_size, 0.0015, 5000000, True)
# Out:
# Cost after iterations 0: 2.091062414630374
# Cost after iterations 10000: 1.415938254470323
# Cost after iterations 20000: 1.4202868794733132
# Cost after iterations 30000: 1.3944125210370117
# Cost after iterations 40000: 1.3688480853249203
# Cost after iterations 50000: 1.3588069531813147
# Cost after iterations 60000: 1.3534483349102833
# Cost after iterations 70000: 1.3503363461206406
# Cost after iterations 80000: 1.3486812397868801
# Cost after iterations 90000: 1.348119302632608
# Cost after iterations 100000: 1.3483383994063083
# Cost after iterations 110000: 1.3488332853390486
# Cost after iterations 120000: 1.3486557298918478
# Cost after iterations 130000: 1.3462636492330908
# Cost after iterations 140000: 1.339808439723668
# Cost after iterations 150000: 1.3281442801108634
# Cost after iterations 160000: 1.3125399888237563
# Cost after iterations 170000: 1.2982257163644004
# Cost after iterations 180000: 1.29125663374601
# Cost after iterations 190000: 1.2914588292275522
# Cost after iterations 200000: 1.2937352196808942
# Cost after iterations 210000: 1.2945858735783742
# Cost after iterations 220000: 1.2935056318531595
# Cost after iterations 230000: 1.2912275610348636
# Cost after iterations 240000: 1.2885455971348376
# Cost after iterations 250000: 1.2859826668965746
# Cost after iterations 260000: 1.283788247778391
# Cost after iterations 270000: 1.2820266520963186
# Cost after iterations 280000: 1.2806664632256828
# Cost after iterations 290000: 1.2796403779534673
# Cost after iterations 300000: 1.2788764357595326
# Cost after iterations 310000: 1.278311095513922
# Cost after iterations 320000: 1.2778929887402248
# Cost after iterations 330000: 1.2775825725708971
# Cost after iterations 340000: 1.2773503106530104
# Cost after iterations 350000: 1.2771745711215874
# Cost after iterations 360000: 1.2770397187165803
# Cost after iterations 370000: 1.2769345494061306
# Cost after iterations 380000: 1.276851074644576
# Cost after iterations 390000: 1.276783609124891
# Cost after iterations 400000: 1.2767281022501713
# Cost after iterations 410000: 1.2766816565565255
# Cost after iterations 420000: 1.2766421852383998
# Cost after iterations 430000: 1.2766081709276749
# Cost after iterations 440000: 1.2765784969612897
# Cost after iterations 450000: 1.2765523298781976
# Cost after iterations 460000: 1.2765290377601994
# Cost after iterations 470000: 1.2765081334640402
# Cost after iterations 480000: 1.2764892350503756
# Cost after iterations 490000: 1.2764720380610222
# Cost after iterations 500000: 1.2764562959566734
# Cost after iterations 510000: 1.2764418061868792
# Cost after iterations 520000: 1.2764284001640722
# Cost after iterations 530000: 1.2764159359610487
# Cost after iterations 540000: 1.2764042929229775
# Cost after iterations 550000: 1.2763933676372596
# Cost after iterations 560000: 1.2763830708751422
# Cost after iterations 570000: 1.2763733252352836
# Cost after iterations 580000: 1.276364063299096
# Cost after iterations 590000: 1.2763552261626563
# Cost after iterations 600000: 1.2763467622487832
# Cost after iterations 610000: 1.2763386263297791
# Cost after iterations 620000: 1.2763307787110463
# Cost after iterations 630000: 1.276323184539481
# Cost after iterations 640000: 1.2763158132105128
# Cost after iterations 4570000: 1.2746680716057344
# Cost after iterations 4580000: 1.2746657128571566
# Cost after iterations 4590000: 1.2746633619140801
# Cost after iterations 4600000: 1.2746610187564142
# Cost after iterations 4610000: 1.2746586833640488
# Cost after iterations 4620000: 1.2746563557168922
# Cost after iterations 4630000: 1.2746540357948408
# Cost after iterations 4640000: 1.2746517235777932
# Cost after iterations 4650000: 1.2746494190456499
# Cost after iterations 4660000: 1.2746471221783087
# Cost after iterations 4670000: 1.2746448329556792
# Cost after iterations 4680000: 1.274642551357662
# Cost after iterations 4690000: 1.2746402773641614
# Cost after iterations 4700000: 1.2746380109551025
# Cost after iterations 4710000: 1.274635752110391
# Cost after iterations 4720000: 1.2746335008099514
# Cost after iterations 4730000: 1.2746312570337128
# Cost after iterations 4740000: 1.2746290207616042
# Cost after iterations 4750000: 1.2746267919735685
# Cost after iterations 4760000: 1.2746245706495551
# Cost after iterations 4770000: 1.2746223567695072
# Cost after iterations 4780000: 1.2746201503133905
# Cost after iterations 4790000: 1.2746179512611804
# Cost after iterations 4800000: 1.2746157595928562
# Cost after iterations 4810000: 1.2746135752884018
# Cost after iterations 4820000: 1.2746113983278207
# Cost after iterations 4830000: 1.2746092286911235
# Cost after iterations 4840000: 1.2746070663583327
# Cost after iterations 4850000: 1.2746049113094775
# Cost after iterations 4860000: 1.2746027635246033
# Cost after iterations 4870000: 1.2746006229837739
# Cost after iterations 4880000: 1.2745984896670586
# Cost after iterations 4890000: 1.274596363554543
# Cost after iterations 4900000: 1.2745942446263276
# Cost after iterations 4910000: 1.2745921328625236
# Cost after iterations 4920000: 1.2745900282432585
# Cost after iterations 4930000: 1.2745879307486678
# Cost after iterations 4940000: 1.2745858403589176
# Cost after iterations 4950000: 1.2745837570541856
# Cost after iterations 4960000: 1.2745816808146635
# Cost after iterations 4970000: 1.2745796116205528
# Cost after iterations 4980000: 1.2745775494520903
# Cost after iterations 4990000: 1.274575494289513
# {'W': array([[-0.0387818 ,  0.03487525, -0.00644312, -0.13517128,  0.03493818,
#          -0.19075978,  0.41345544, -0.02774836,  0.16649869, -0.0457511 ,
#           0.30787757, -0.3639227 , -0.01314615,  0.02418396, -0.05277873],
#         [-0.0701003 ,  1.28536946, -0.39172315, -0.28696187, -0.17578864,
#           0.86835184,  0.57298327, -0.15354046,  0.36959689,  0.06900344,
#           0.79377095,  0.71983465, -0.45092191,  0.05058545, -0.65936353],
#         [-0.08216667, -0.04196898, -0.28474863,  0.16387482, -0.14971857,
#          -0.24494578, -0.19308469, -0.00986134, -0.067033  ,  0.19006137,
#           0.15116042,  0.22565116, -0.26631781,  0.08724547, -0.17605869],
#         [-0.72927552, -0.46850418,  0.37192182,  0.00167938, -0.14413067,
#          -0.1068031 ,  0.08377181,  0.13063409,  0.11820384,  0.33253868,
#           0.14639407, -0.40520038,  0.46817659,  0.1316254 ,  0.3605071 ],
#         [ 0.00672921, -0.52756656,  0.28742063,  0.24614215, -0.09489964,
